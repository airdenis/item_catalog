# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 1: What's next
#
# ## CHAPTER 1: Leveraging Your Skillset
#
# Skills
#
# Congratulations! After months of hard work of learning and building your portfolio, you’re ready to get started as a professional Full Stack Developer. Let's recap what you've accomplished:
#
# * You built a tool to analyze website data from a SQL database
# * You created a database-backed web application with full CRUD capability
# * You deployed your web application to a secure, live web server
#
# With the completion of this Nanodegree program and extracurricular content, you should feel comfortable adding a diverse set of technical skills to your LinkedIn profile. Here are a few to get you started!
# * HTML
# * Python
# * JavaScript
# * Git
# * GitHub
# * Unix shell
# * Application Programming Interfaces (API)
# * Relational Databases
# * Python Database API
# * SQL
# * PostgreSQL
# * HTTP
# * Transmission Control Protocol (TCP)
# * Servers
# * CRUD
# * Authentication
# * RESTful API
# * Vagrant
# * Linux Server
# * WSGI
# * Apache
# * Web Accessibility
# * ARIA
# * Asynchronous JavaScript
# * AJAX
#
# ## CHAPTER 2: Moving Forward
#
# ### Further Learning
#
# With your new skills in front end web development, you can extend your projects with additional functionality, or even contribute to open-source projects you find on the web. The sky's the limit.
#
# Beyond that, feel free to further your Python skills and explore more programs available from Udacity:
#
# #### Machine Learning
#
# In this program, you’ll master valuable [Machine Learning](https://www.udacity.com/course/machine-learning-engineer-nanodegree--nd009t) skills that are in demand across countless industries. Investment levels in this space continue to rise, thousands of highly-valued startups have entered the field, and demand for machine learning talent shows no signs of leveling. Program graduates emerge uniquely prepared to excel in machine learning roles.
#
# #### Artificial Intelligence
#
# Learn from the world’s foremost [AI](https://www.udacity.com/course/ai-artificial-intelligence-nanodegree--nd898) experts, and develop a deep understanding of algorithms being applied to real-world problems in natural language processing, computer vision, bioinformatics, and more. Practice a structured approach for applying these techniques to new challenges, and emerge fully prepared to advance in the field.
#
# #### Data Analyst
#
# In this program, you’ll master the skills you need to establish a successful [data science](https://www.udacity.com/course/data-scientist-nanodegree--nd025) career. Our curriculum was developed with leading industry partners to ensure students master the most cutting-edge skills. Demand for qualified employees with advanced data skills has never been higher, and graduates will emerge fully job-ready.
#
# #### Data Scientist
#
# Udacity has collaborated with industry leaders to offer a world-class learning experience built to advance your data science career. Get hands-on experience running data pipelines, designing experiments, building recommendation systems, and more. Enjoy personalized support as you master in-demand skills that qualify you for high-value jobs in the field.
#
# ### Web Development
#
# Looking to further your web development skills after the Full Stack Web Developer Nanodegree program? Check out the following:
#
# #### React
#
# React is a powerful JavaScript library ideal for building interactive, data-driven user interfaces. With the [React](https://www.udacity.com/course/react-nanodegree--nd019) Nanodegree program, you'll learn how to build dynamic single-page applications, leverage advanced techniques to manage global application state, and build native mobile (i.e., iOS and Android) apps -- all with JavaScript!
#
# #### Mobile Web Specialist
#
# Looking to design and build web experiences for mobile devices? The [Mobile Web Specialist](https://www.udacity.com/course/mobile-web-specialist-nanodegree--nd024) Nanodegree program will prepare intermediate programmers for a career in mobile web application development. In addition, you'll be fully prepared to earn the Google Mobile Web Specialist Certification, offered directly by Google.
#
# ### Staying in Touch
#
# This is an exciting time and we’re so glad you chose to learn with us. Make sure to stay in touch with us in our [Career Portal](https://classroom.udacity.com/career/main) and [social media](https://www.facebook.com/Udacity/).
