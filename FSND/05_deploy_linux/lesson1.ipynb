# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 1: Linux Security
#
#
# ## CHAPTER 1: Intro to Linux Security

# %%
id = 'PucDEG4ou_k'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: The Rule of Least Privilege

# %%
id = 'F-PlOomQkAs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Becoming a Super User

# %%
id = 'fC6eWTMslt4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: sudo vs. su

# %%
id = '_nH4vpivD3Y'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Package Source Lists

# %%
id = 'MpDaWOUA-BY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Updating Available Package Lists

# %%
id = 'BmiZxCkKwbo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Upgrading Installed Packages

# %%
id = 'q-RRw3kD4MI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: Other Package Related Tasks

# %%
id = 'vBnEmhNZ04Y'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Discovering Packages

# %%
id = 'rlfAlDQzQEs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Quiz: Using Package Search

# %%
id = 'jeH4_AKgGls'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# [Trusty package list.](http://packages.ubuntu.com/trusty/)
#
# #### Answer:

# %%
id = 'lPP95ZbGZBU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 11: Using Finger

# %%
id = 'lskID0MNWXY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 12: Introduction to /etc/passwd

# %%
id = 'McsfRuZq8vU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### ``/etc/passwd``
#
# This is a very important file on your system! It's used to keep track of all users on the system. Run cat /etc/passwd and look at the output; each line is organized in this format:
# ```
# username:password:UID:GID:UID info:home directory:command/shell
# ```
# Let’s run through what each of those mean:
#
# * ``username``: the user’s login name
# * ``password``: the password, will simply be an x if it’s encrypted
# * ``user ID (UID)``: the user’s ID number in the system. 0 is root, 1-99 are for predefined users, and 100-999 are for other system accounts
# * ``group ID (GID)``: Primary group ID, stored in /etc/group.
# * ``user ID info``: Metadata about the user; phone, email, name, etc.
# * ``home directory``: Where the user is sent upon login. Generally /home/
# * ``command/shell``: The absolute path of a command or shell (usually /bin/bash). Does not have to be a shell though!
#
#
# ## CHAPTER 13: Quiz: Reading /etc/passwd Entries

# %%
id = 'Ip14M8vb48M'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = '_OC7MKBukIw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER: Quiz:  User Account Info

# %%
id = 'tiCOY9Qoeps'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'mnH-I-yjZ4c'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 15: Introduction to User Management

# %%
id = 'DgFnxsFhUA0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 16: Creating a New User

# %%
id = 'cprjSyaajqE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 17: Connecting as the New User

# %%
id = 'bDpQxtVLTPw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 18: Introduction to etc sudoers

# %%
id = 'f28nZ2ubYFk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 19: Giving Sudo Access

# %%
id = '32u1qTPN5eQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 20: Quiz: Resetting Passwords

# %%
id = 'Xqw4Ajl9fzM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'AoifNF8VPI0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 21: Another Authentication Method

# %%
id = 'NQUXLUm8Fug'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 22: Public Key Encryption

# %%
id = 'KuCt1GhzKJE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 23: Generating Key Pairs

# %%
id = 'afOCp8d60U8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 24: Quiz: Supported Key Types

# %%
id = 'Z9cJ6rnXNXY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'QzmiVAWlw-Y'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 25: Installing a Public Key

# %%
id = 'k5JTVI6c7w8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 26: Forcing Key Based Authentication

# %%
id = 'NOPYGp2Ixvs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 27: Introduction to File Permissions

# %%
id = 'dN3u5bbyWvA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 28: Owners and Groups

# %%
id = 'Co-EWQM-eFU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 29: Quiz: Identifying Owners and Groups

# %%
id = '5MyCuq_j7Wc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Errata
#
# The "Udacity-provided developer environment" referred to in the quiz is no longer supported. Instead, refer to files in your Vagrant-managed virtual machine.
#
# #### Answer:

# %%
id = 'TU92uFJNmFo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 30: Octal Permissions [missing dialogue]

# %%
id = 'fwgX_mHeSJM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 31: Quiz: Octal File Permissions

# %%
id = '9_nXVxp4iz0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = '-amFiBpK5eY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 32: chgrp and chown

# %%
id = 'IcSxrW5afBA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Errata
#
# The ``.bash_history`` file is created by the ``bash`` shell the first time you log out of your Linux system. This means that if you are logging into the system for the first time, it won't have been created yet. If you log out and log back in (e.g. ``vagrant ssh`` if you're using Vagrant here) then the file will be created.
#
# You can also experiment with ``chown`` and ``chgrp`` using another file. To create an empty file named ``testfile``, use the command ``touch testfile``.
#
#
# ## CHAPTER 33: Intro to Ports

# %%
id = 're_hW0AS1qA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 34: Default Ports for Popular Services

# %%
id = 'N_bnwou-GYw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'jlRLiexlnSY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 35: Intro to Firewalls

# %%
id = 'X_oydB2TeLQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 36: Intro to UFW

# %%
id = 'NYHrggI0wK0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 37: Configuring Ports in UFW

# %%
id = 'n3PC04x09gc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 38: Conclusion

# %%
id = 'HXvm69aqOQk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Here are a few tutorials that will walk you through how to configure your server in a variety of use cases:
#
# * ["LAMP" Stack (Linux, Apache, MySQL, PHP)](https://www.digitalocean.com/community/tutorials/how-to-install-linux-apache-mysql-php-lamp-stack-on-ubuntu-14-04)
# * ["LEMP" Stack (Linux, nginx, MySQL, PHP)](https://www.digitalocean.com/community/tutorials/how-to-install-linux-nginx-mysql-php-lemp-stack-on-ubuntu-14-04)
# * [PEPS Mail and File Storage](https://www.digitalocean.com/community/tutorials/how-to-run-your-own-mail-server-and-file-storage-with-peps-on-ubuntu-14-04)
# * [Mail-in-a-Box Email Server](https://www.digitalocean.com/community/tutorials/how-to-run-your-own-mail-server-with-mail-in-a-box-on-ubuntu-14-04)
# * [Lita IRC Chat Bot](https://www.digitalocean.com/community/tutorials/how-to-install-the-lita-chat-bot-for-irc-on-ubuntu-14-04)
