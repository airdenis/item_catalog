# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # Lesson 1
# ### Welcome to the Full Stack Web Developer Nanodegree Program
# Welcome! Our goal is to equip you with the skills you’ll need to become a professional Full Stack Developer. Let’s get started!
#
# ## CHAPTER 1

# %%
id = 'wNXDjDvA7wU'
YouTubeVideo(id=id, width=600)

# %%
id = 'FFd0nrKLmVI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Projects in the Full Stack Nanodegree Program
#
# ### Logs Analysis
#
# You will use an SQL database to analyze logs from a web service and present it as a report. The report includes summary information such as the most popular pages on the site, as well as an analysis of the site's availability based on error codes.
#
# ![logs.png](attachment:logs.png)
# Working with the database in the Logs Analysis project.
#
#
# ### Item Catalog
#
# You will develop an application that provides a list of items within a variety of categories, as well as a user registration and authentication system. Registered users will have the ability to post, edit and delete their own items.
#
# ![item-catalog.png](attachment:item-catalog.png)
# Browsing a collection of sporting items in the Item Catalog project.
#
#
# ### Linux Server Configuration
#
# In this project, you'll secure and configure a Linux server running in the cloud, and deploy one of your previous projects to it. You'll apply system administration skills to set up the server so that your application can securely talk to a locally hosted database, and run your project code behind an Apache web server.
#
# ![server.png](attachment:server.png)
# Creating an SSH key in the Linux Server Configuration project.

# %% [markdown]
# ## CHAPTER 3: Projects and Progress

# %%
id = 'Z9ZLMQWsbsk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Program Structure
#
# ### Welcome to the Program!
#
# We've designed the program to be four months long to accommodate your schedule while helping you become a professional Full Stack Developer as quickly as possible.
#
# You won't be going through this program alone. You will be learning as a part of a community of like-minded individuals, who will be challenging and supporting you every step of the way as you work toward a common goal. Make sure to visit your Study Hall right here in the classroom for project help, networking, and collaboration with your classmates throughout your program!
#
#
# ### The Road Ahead
#
# Let's talk briefly about what the road ahead looks like. The program is made up of four main courses and some elective courses. To help you manage your time in each course, gauge your progress, and make sure you get the most out of the program, each of the three projects has a deadline. Now, deadlines can sound scary, but they’re not. They are an effective tool to help you finish the program and achieve your career goals. You just need to keep them in the back of your mind as you progress through the course and build in some buffer time for project planning, debugging, and other things that may come up. Building in extra buffer time will help you be less stressed out and remain on track.

# %% [markdown]
# ## CHAPTER 5: Program Deadlines
#
# It is strongly recommended that you submit your projects in accordance with the deadlines noted in the classroom in order to stay on track for completing the program. If something unexpected comes up and you have to submit your project a few days after the deadline, that’s fine. By sticking to these deadlines, you’ll ensure that you have enough time to revise your project (if needed) and discuss the project with students who are at the same point in the curriculum.
#
# Please keep in mind that you must submit and pass all of the projects by the Term End Date. As a reminder, after the 4-month term, you will no longer be able to access the course materials.
#
#
# ### FAQ
#
# #### Is this program self-paced?
#
# No. The Full Stack Web Developer Nanodegree Program has a fixed start and end dates, and you must complete all assigned projects by the Term End Date. However, projects may be submitted at any time during a Term, and individual project deadlines are recommendations, not requirements. So within a Term, there is some opportunity to work at your own pace. But you should plan to follow our recommended timeline, as this will best enable you to keep pace with your peers and complete the program on time.
#
#
# #### What are my options if I don’t complete the program on time?
#
# To resume access to the course, you would need to re-enroll in a new term and pay the associated enrollment fees again. Your coursework progress and your project progress will be saved, so you can start exactly where you left off.

# %% [markdown]
# ## CHAPTER 6: How does project Submission Work?

# %%
id = 'jCJa_VP6qgg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Integrity and Mindset

# %%
id = 'zCOr3O50gQM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: Time Management
#
# Think about when you'll be able to fit your Nanodegree program into your schedule. We recommend blocking off at least 4-5 separate learning sessions every week, with each one lasting 2-3 hours.
#
# Please go into your calendar and schedule time to work on your Nanodegree program for the next two weeks. Remember, consistent and frequent learning is the key to achieving your learning goals!
#
# We've put together a sample learning plan for your first week in the program, to help highlight and plan your first few days. You can find that document [here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/August/5b743de4_fsnd-learning-plan/fsnd-learning-plan.pdf) or in the Nanodegree Resources section in the sidebar.

# %%
id = 'd-VfUw7wNEQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Learning Strategies
#
# Digging in and wrestling with the material is crucial to gaining a deep understanding of the material and retaining it in your long-term memory.
#
# Research shows that we gain a deeper understanding of what we've learned when we explain it to someone else. After learning a certain concept and before going to the next lecture, try summarizing the concept in your head. Imagine that you’re trying to explain it to someone...or better yet go and actually explain it to someone! You can do this in person, on a video call with a friend, or you can share your insights with your fellow learners right in the classroom!
#
# Try out these strategies to improve your understanding and your retention of newly learned material:
#
# 1. Ask yourself follow-up questions about the material. Here's an example: "If I changed X in the example, would the code still work? How would it change?"
#
# 2. Connect the new information to something you already know. In which ways are the two similar? How are they different?
#
# 3. Draw out the information in a visual form. Share your diagrams, visual models, or flowcharts.
#
# These strategies will help you gain a deeper understanding of the material, help your classmates learn the material, and have a lot of fun while learning!

# %% [markdown]
# ## CHAPTER 10: Growth Mindset
#
# Maintaining a growth mindset is crucial in any learning endeavor, and it's no different here! This program is hard, and it will require you to not only manage your time effectively but also to go beyond your comfort zone, ask questions, and continually challenge yourself.
#
# Remember that it often takes multiple attempts to pass a project. It also takes time to really understand a new concept. It may seem like you’re the only one who’s having trouble. But I guarantee you that that’s not the case. I had trouble with this content when I first learned it. I want to encourage you to keep going. Try a different learning tactic, use the available mentorship resources, and take advantage of your amazing community.
#
# We are all here to support you, and we’re excited to have the opportunity to help you accomplish your goals.
#
# Not passing a project or not understanding the content after reviewing it a bunch of times is not failure. It is an opportunity to really challenge yourself. With each attempt, you’re closer to passing. With each attempt, you’re closer to mastering this content. With each attempt, you are closer to achieving your goal.

# %% [markdown]
# ## CHAPTER 11: Community Guidelines
#
# Your experience in the Nanodegree program and community should be an engaging, fulfilling, and positive one. As such, we have outlined the following system for reporting behavior that does not live up to Udacity’s standards, so it can quickly be addressed by our staff.
#
# All reports of suspected violations to the [TOS](https://www.udacity.com/legal/terms-of-use), [Community Code of Conduct](https://www.udacity.com/legal/community-guidelines) or [Honor Code](https://www.udacity.com/legal/community-guidelines) should be submitted to report@udacity.com and will be reviewed. If you witness or are experiencing any violations of our policies please get in touch with us. Below prohibited actions as set forth on our [Community Code of Conduct](https://www.udacity.com/legal/community-guidelines):
#
# * **Harassment**: Inappropriate, harassing, abusive, discriminatory, derogatory or violent comments or conduct.
# * **Discrimination**: Offensive comments related to gender or gender identity, sexual orientation, race, ethnicity, religion, national origin, disability or disease
# * **Distributing inappropriate content**: Use of sexual, violent, graphic, or derogatory images
# * **Bullying**: Deliberate intimidation, threats of violence or violent language directed against another person
# * **Sexual harassment**: Unwelcome sexual attention
# * **Defamation**: Obscene, fraudulent, indecent, or libelous acts that defame, abuse, harass, discriminate against or threaten others
# * **Plagiarism**: will not cheat on any homework assignment, projects or exams for the Online Courses and, specifically, will not plagiarize materials created by others
# * **Self-injury or Suicide**: We do not encourage community postings in Study Groups related to self-injury or suicide. If you or someone you know is exhibiting signs of self-injury or suicide, find help at the [Suicide Prevention Lifeline](https://suicidepreventionlifeline.org/) in the U.S. and [Befrienders.org](https://www.befrienders.org/) globally.
#
# When a potential violation is brought to our attention, we will make every effort to investigate the case thoroughly and make a decision that is fair to all parties.
#
# Thank you,
#
# The Udacity Team

# %% [markdown]
# ## CHAPTER 12: Final Tips

# %%
id = '1ZVBvM54hQw'
YouTubeVideo(id=id, width=600)
