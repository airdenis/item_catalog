# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 4: Interactive Development
#
# ## CHAPTER 1: Lesson 4 Introduction

# %%
id = 'kI_0WcxsVAE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Interactive Development

# %%
id = 'feKv4wheDeU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Quiz: Tackling a Complex Project

# %%
id = 'Hq7pqDSkmvo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Mockups Exercise

# %%
id = 'uEds1PgYoaw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Adding Routes

# %%
id = 'Ek0i3taiJf4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Adding Templates and Forms

# %%
id = 'Cc5X0TUGyOM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The source code is available in the Downloadables section.
#
# #### Supporting Materials
# [fakeMenuItems.txt](https://www.udacity.com/api/nodes/3607568911/supplemental_media/fakemenuitemstxt/download)
#
#
# ## CHAPTER 7: CRUD Functionality

# %%
id = 'Ni6Z60_SjIU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: API Endpoints

# %%
id = 'VaVsCeMSM4c'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Styling Your App

# %%
id = '2wGoiNu7-g0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# A very basic CSS file can be found [here](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-4/Final-Project/static/styles.css) or in the Downloadables section
#
# #### Supporting Materials
# [static.zip](https://www.udacity.com/api/nodes/3607568917/supplemental_media/staticzip/download)
#
#
# ## CHAPTER 10: Wrap-Up

# %%
id = 'M7h_f_-ubro'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# You can view [this article](http://flask.pocoo.org/docs/0.10/deploying/) on deploying Flask applications, but I highly recommend adding some [security](https://pythonhosted.org/Flask-Security/) to your application before publishing it on the internet.
#
# A basic version of the final project can be found [here](https://github.com/lobrown/Full-Stack-Foundations/tree/master/Lesson-4/Final-Project).
