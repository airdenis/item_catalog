# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# ## LESSON 13: Lesson 3 Intro
#
# ### CHAPTER 1: Lesson 3 Intro

# %%
id = 'nnHhvbAqxNU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# http://flask.pocoo.org/docs/0.10/tutorial/
#
#
# ## CHAPTER 2: API Endpoints with Flask

# %%
id = 'Mzyzam8lRY4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Click to view the [Flask Quickstart Documentation](http://flask.pocoo.org/docs/0.10/quickstart/).
#
#
# ## CHAPTER 3: Making an Endpoint with Flask Quiz

# %%
id = 'c45YcTFk1G4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the [Starter Code](https://github.com/udacity/APIs/tree/master/Lesson_3/03_Making%20an%20Endpoint%20with%20Flask/Starter%20Code) here.
#
# Correction in video: In line 7, rename the function to puppiesFunction() and in line 13 rename the function to puppiesFunctionId(id). CORRECTION: The second function name here will be puppiesFunctionId(id)
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_3/03_Making%20an%20Endpoint%20with%20Flask/Solution%20Code) here.
#
# #### Answer:

# %%
id = 'sZc5DczXtDM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Quiz: Respond to Different Kinds of Requests

# %%
id = 'EMFPzG_gWzU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the [starter code](https://github.com/udacity/APIs/tree/master/Lesson_3/04_Responding%20to%20Different%20Types%20of%20Requests/Starter%20Code) here.
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_3/04_Responding%20to%20Different%20Types%20of%20Requests/Solution%20Code) here.
#
#
# #### Answer:

# %%
id = 'eyKmxj0K2JQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Quiz: Serializing Data from the Database

# %%
id = 'nOpWUyZm7Jw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the [starter code](https://github.com/udacity/APIs/tree/master/Lesson_3/05_Serializing%20data%20from%20the%20database/Starter%20Code) for this exercise.
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_3/05_Serializing%20data%20from%20the%20database/Solution%20Code) for this exercise.
#
# ### Errata:
#
# The code in the starter and solution files in the Github repo has been updated slightly from the code in the video. For instance, the correct route for ``puppiesFunction`` is ``"/puppies"`` (with no slash), not ``"/puppies/"``. When in doubt, refer to the code and the tests for it.
#
#
# #### Answer:

# %%
id = 'uWA6-S0X4Ys'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Quiz: Adding features to your Mashup

# %%
id = '0i6EyoHvNRM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the [starter code](https://github.com/udacity/APIs/tree/master/Lesson_3/06_Adding%20Features%20to%20your%20Mashup/Starter%20Code) for this exercise.
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_3/06_Adding%20Features%20to%20your%20Mashup/Solution%20Code) for this exercise.
#
#
# #### Answer:

# %%
id = 'jsQtM1p-F8U'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Lesson 3 Wrap Up

# %%
id = 'YHXSqqVBvuE'
YouTubeVideo(id=id, width=600)
