# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 3: Developing with frameworks
#
# ## CHAPTER 1: Introducing Frameworks and Flask

# %%
id = 'AlU6oSmwIn0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Lesson 3 Overview

# %%
id = 'lLt_EG11kqA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Running Your First Flask Application

# %%
id = 'bzX_auqvePs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: First Flask App Quiz

# %%
id = 'ObU3Q6TCsDU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ![crud3.png](attachment:crud3.png)
#
# #### Answer:
# the localhost:5000 is not gonna work, but /hello will work without changes
#
# View the code for [project.py](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/01_First-Flask-App/project.py)
#
# ### Note:
# ```
# Try amazon.com/index.html instead of amazon.com/index
# ```
#
# ## CHAPTER 5: Adding Database to Flask Application

# %%
id = 'eX68y19FeEg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/02_Adding-Database-to-Flask-Application/project.py
#
# ## CHAPTER 6: Adding Database to Flask Application Quiz

# %%
id = 'JBb1BOONt8o'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# [Code here](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/03_-Listing-Menu-Items-with-Flask/project.py)
#
# Supporting Materials
# [project.py](https://www.udacity.com/api/nodes/3624558612/supplemental_media/projectpy/download)
#
# #### Answer:

# %%
id = 'jZC6cKcAyVY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Routing

# %%
id = 'HF27bMg6HsM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Since the HelloWorld(restaurant_id) didn't make much sense, I changed it to restaurantMenu(restaurant_id) in the solution code.
#
# Before you run the code, make sure to wipe your database and re-initialize it with lotsofmenus.py! The changes made in in the previous videos will prevent the code from working otherwise.
#
# ### Flask Documentation on Routing :
#
# http://flask.pocoo.org/docs/0.10/quickstart/#routing
#
# ### Code from this lesson:
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/04_Routing/project.py
#
# ## CHAPTER 8: Quiz: Routing Create Quiz

# %%
id = 'MHknXqyReMM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the template [code here](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/05_Routing-Create-Quiz-Template-Code/project.py).
#
# Click to view the [solution code](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/06_Routing-Quiz-Solution/project.py) for this challenge.
#
# Supporting Materials
# [project.py](https://www.udacity.com/api/nodes/3624558616/supplemental_media/projectpy/download)
#
# ![crud5.png](attachment:crud5.png)
#
#
# #### Answer:

# %%
id = 'DCuDRYmJlKo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Templates

# %%
id = 'JjOgMeHuaZo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Note:
#
# [HTML Character Escaping](http://en.wikipedia.org/wiki/HTML#Character_and_entity_references) is a way of writing special characters inside of HTML code, this is a different concept from the HTML escaping with python code shown in this lesson.
#
# http://en.wikipedia.org/wiki/HTML#Character_and_entity_references
#
#
# ## CHAPTER 10: Templates Quiz

# %%
id = 'FbfVRCPXG5o'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/07_Menu-Template-Quiz/menu.html
#
# Supporting Materials
# [menu.html](https://www.udacity.com/api/nodes/3601619034/supplemental_media/menuhtml/download)
#
# #### Answer:
#
# ![crud4.png](attachment:crud4.png)
# this symbols represent the logic 'for' operation in .html
#
# #### Answer:

# %%
id = 'ItqZbUJ5Gv8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 11: URL for Quiz

# %%
id = 'tfRwbW8ojJo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Download the menu.html file. Add url_for() links to edit and delete each menu item
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/07_Menu-Template-Quiz/menu.html
#
# Flask Documentation for url_for can be found [here](http://flask.pocoo.org/docs/0.10/quickstart/#url-building).
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/10_url_for-Solution/menu.html
#
# Supporting Materials
# [menu.html](https://www.udacity.com/api/nodes/3624558622/supplemental_media/menuhtml/download)
#
# ![crud6.png](attachment:crud6.png)
#
# #### Answer:

# %%
id = 'b3NBHGwK994'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 12: Form Requests and Redirects

# %%
id = 'kSyofBId8tw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# You can find the code for this exercise [here](https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/11_form-requests-and-redirects).
#
# __Errata__: If you've been following along with your own code, you'll need to make sure to add a link to the ``menu.html`` file to actually get to the new menu item page. Remember that the ``restaurant`` object has been passed into the template, so we have access to its details.
# ```html
# <a href = '{{url_for('newMenuItem', restaurant_id = restaurant.id) }}'>
# Create New Item</a>
# ```
#
# ## CHAPTER 13: Edit Menu Item Form Quiz

# %%
id = 'sbJ5VpaWjRw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/12_Edit-Menu-Form
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/13_Edit-Menu-Form-Solution/editmenuitem.html
#
# Supporting Materials
#
# * [project.py](https://www.udacity.com/api/nodes/3624558626/supplemental_media/projectpy/download)
# * [editmenuitem.html](https://www.udacity.com/api/nodes/3624558626/supplemental_media/editmenuitemhtml/download)
#
# #### Answer:

# %%
id = 'wV-X1Cg675k'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 14: Quiz: Delete Menu Item

# %%
id = '1X0Cm45d0yE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/14_Delete-Menu-Item/deletemenuitem.html
#
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/15_Delete-Menu-Item-Solution
#
# Supporting Materials
# * [deletemenuitem.html](https://www.udacity.com/api/nodes/3624558629/supplemental_media/deletemenuitemhtml/download)
# * [project.py](https://www.udacity.com/api/nodes/3624558630/supplemental_media/projectpy/download)
#
# #### Answer:

# %%
id = 'stHPjdeAecU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 15: Message Flashing

# %%
id = '-vNN7vc5oyQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Errata:
#
# Around 1:20 in the video, the instructor mentions adding code to ``newmenuitem.html``. However, the file he is actually editing is ``menu.html``. To follow along with this instruction, you should edit ``menu.html`` and not ``newmenuitem.html``.
#
# ### Instructor notes:
#
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/16_Flash-Messaging
#
# Click here to learn more about the 'with' statement in python: http://effbot.org/zone/python-with-statement.htm
#
# ## CHAPTER 16: Message Flashing Quiz

# %%
id = 'NP2ykGcbmSM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/16_Flash-Messaging
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-3/17_Flash-Messaging-Solution/project.py
#
#
# #### Answer:

# %%
id = 'vb85_7lsqr4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 17: Quiz: Styling

# %%
id = 'UVTWaDMMr6Q'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/18_Styling
#
# ### Supporting Materials
# * [static.zip](http://video.udacity-data.com.s3.amazonaws.com/topher/2017/September/59cd6d87_static/static.zip)
# * [templates.zip](http://video.udacity-data.com.s3.amazonaws.com/topher/2017/September/59cd6d95_templates/templates.zip)
#
#
# ## CHAPTER 18: Responding With JSON

# %%
id = 'BIPRKkPtXy8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/19_Responding-with-JSON
#
# * RESTful: http://en.wikipedia.org/wiki/Representational_state_transfer
#
# * JSON: http://en.wikipedia.org/wiki/JSON
#
#
# ## CHAPTER 19: JSON Quiz

# %%
id = '0vnMvkalXuE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/19_Responding-with-JSON
#
# The project.py and database_setup.py files used in this lesson are available in the Downloadables section.
#
# https://github.com/udacity/Full-Stack-Foundations/tree/master/Lesson-3/20_JSON-Solution
#
# #### Supporting Materials
# * [project.py](https://www.udacity.com/api/nodes/3642758697/supplemental_media/projectpy/download)
# * [database_setup.py](https://www.udacity.com/api/nodes/3642758697/supplemental_media/database-setuppy/download)
#
# #### Answer:

# %%
id = 'jmHJOV2jrwc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 20: Lesson 3 Wrap-Up

# %%
id = 'EyqHUy6uiQc'
YouTubeVideo(id=id, width=600)
