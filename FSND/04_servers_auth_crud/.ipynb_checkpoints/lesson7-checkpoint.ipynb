# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 7: Local Permission System
#
# ## CHAPTER 1: Lesson 3 Introduction

# %%
id = 'nNBMggxZNj8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Implementing a Local Permission System

# %%
id = 'uog6ImM3IWo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Updating the User Model

# %%
id = 'KyWbG-OierA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * [database_setup.py](https://github.com/udacity/ud330/blob/master/Lesson3/step2Quiz/database_setup.py)
# * [lotsofmenus.py](https://github.com/udacity/ud330/blob/master/Lesson3/step2Quiz/lotsofmenus.py)
#
# #### Answer:

# %%
id = 'aHRTFkT1oug'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Creating a New User

# %%
id = 'SSWfr2sBBCM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# You can view these helper functions on line 131 of [project.py](https://github.com/udacity/ud330/blob/master/Lesson3/step2Quiz/project.py)
#
# ## CHAPTER 5: Quiz: Obtaining Credentials of an Existing User

# %%
id = 'wb20eVxwq7g'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'oLGaOctmL24'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Quiz: Protect Menu Pages

# %%
id = 'Bu8NINOUsvo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Click to view the [publicmenu.html](https://github.com/udacity/ud330/blob/master/Lesson3/step3/templates/publicmenu.html) and [publicrestaurants.html](https://github.com/udacity/ud330/blob/master/Lesson3/step3/templates/publicrestaurants.html) templates.
#
# ### Note:
#
# In order to view the profile picture of the creator of each menu, add code to your project.py file to query the creator:
# ```python
# creator = getUserInfo(restaurant.user_id)
# ```
# then pass in the creator object when you render the template:
# ```python
# return render_template('publicmenu.html', items = items, restaurant = restaurant, creator= creator)
# ```
# Inside your templates you can now use ``{{creator.picture}}`` and ``{{creator.name}}`` to share the name and picture of each restaurant creator.
#
#
# #### Answer:

# %%
id = 'eLPcDIiv75U'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Wrap-Up Lesson 3

# %%
id = 'QoSVT67PyHQ'
YouTubeVideo(id=id, width=600)
