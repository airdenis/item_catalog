# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# ## LESSON 14: Securing your API
#
# ## CHAPTER 1: Lesson 4 Intro

# %%
id = '7BSDajjMsfU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Adding Users and Logins

# %%
id = 'RFQ6mM3BzAA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the code from this exercise [here](https://github.com/udacity/APIs/tree/master/Lesson_4/02_Adding%20Users%20and%20Logins).
# >
# >    *__Note:__*
# >
# >    *The API for ``passlib`` is changing. Instead of using ``.encrypt()``, that function has been replaced with ``.hash()`` If you're trying to find the documentation for ``.encrypt()``, look for the documentation for ``.hash()`` instead: http://passlib.readthedocs.io/en/stable/lib/passlib.ifc.html#passlib.ifc.PasswordHash.hash*
# >
#
#
# ## CHAPTER 3: User Registration

# %%
id = 'Qp6AvfxDNW0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# At the end of the video, Lorenzo recommends performing secure login over HTTPS. For more about HTTPS (HTTP over TLS encryption), see these courses —
#
# * [Client-Server Communication](https://udacity.com/courses/ud897)
# * [HTTP and Web Servers](https://udacity.com/courses/ud303)
#
# You can find the code for this video [here](https://github.com/udacity/APIs/tree/master/Lesson_4/03%20_User%20Registration).
#
# ## CHAPTER 4: Password Protecting a Resource

# %%
id = 'Blj-yLrWGI0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the code for this video [here](https://github.com/udacity/APIs/tree/master/Lesson_4/04_Password%20Protecting%20a%20Resource).
#
# ### Errata:
#
# The API for the Flask HTTP Basic Authentication library has changed since this course was created. The module has been renamed from ``flask.ext.httpauth`` to ``flask_httpauth``. Today, the recommended ``import`` statement is as follows:
# ```python
# from flask_httpauth import HTTPBasicAuth
# ```
# The older module name will still work, but will give you a warning message.
#
# See examples in the [flask_httpauth documentation.](https://flask-httpauth.readthedocs.io/en/latest/)
#
#
# ## CHAPTER 5: Mom & Pop’s Bagel Shop

# %%
id = 'HpbqPH8Upk4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the starter code for this activity [here](https://github.com/udacity/APIs/tree/master/Lesson_4/05_Mom%20%26%20Pop%E2%80%99s%20Bagel%20Shop/starter_code).
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_4/05_Mom%20%26%20Pop%E2%80%99s%20Bagel%20Shop/Solution%20Code) for this activity.
#
# #### Answer:

# %%
id = 'fMdLjHEPs4Q'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Token Based Authentication

# %%
id = 'woNZJMSNbuo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Implementing Token Based Authentication in Flask

# %%
id = 'UwmHRTGalIY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the code for this activity [here](https://github.com/udacity/APIs/tree/master/Lesson_4/07_Implementing%20Token-Based%20Authentication%20in%20Flask).
#
#
# ## CHAPTER 8: Quiz: Regal Tree Foods

# %%
id = 'DoEplybiTrE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The starter code for this activity is available [here](https://github.com/udacity/APIs/tree/master/Lesson_4/08%20_Regal%20Tree%20Foods/starter_code).
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_4/08%20_Regal%20Tree%20Foods/Solution%20Code) for this activity.
#
#
# #### Answer:

# %%
id = 'tMxMnUVqtzU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: OAuth 2.0

# %%
id = 'HICiswQsp_s'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Adding OAuth 2.0 for Authentication

# %%
id = '2MHMgyByoZQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The code for this activity is available [here](https://github.com/udacity/APIs/tree/master/Lesson_4/10_Adding%20OAuth%202.0%20for%20Authentication).
#
#
# ## CHAPTER 11: Pale Kale Salads & Smoothies

# %%
id = '0LHQ-xeESHI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the starter code for this activity [here](https://github.com/udacity/APIs/tree/master/Lesson_4/11_Pale%20Kale%20Ocean%20Eats/starter_code).
#
# You'll need to replace the ``client_id`` on line 14 of ``clientOAuth.html`` with your own Google client ID.
#
# View the solution code to this exercise [here](https://github.com/udacity/APIs/tree/master/Lesson_4/11_Pale%20Kale%20Ocean%20Eats/Solution%20Code).
#
# #### Answer:

# %%
id = '6g9nzCVeBLc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 12: Rate Limiting

# %%
id = 'o21P4Oh_0pM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 13: Rate Limiting Exercise

# %%
id = 'j-yu4yJbIS4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View the code from this exercise [here](https://github.com/udacity/APIs/tree/master/Lesson_4/12_Rate%20Limiting).
#
#
# ## CHAPTER 14: Quiz: Bargain Mart

# %%
id = '8ylrDfTIJSM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The starter code for this exercise can be viewed [here](https://github.com/udacity/APIs/tree/master/Lesson_4/13_BargainMart/Starter%20Code).
#
# ### Additional Note
#
# It is best to have two terminals open that are logged into the Vagrant VM. In the first one, start the Redis server with this command:
# ```
# redis-server &
# ```
# Then press the return key to get back to the command prompt (the "&" character allows this to happen). Then run the ``views.py`` Python script, like this:
# ```
# python views.py
# ```
# Now move to the 2nd Vagrant terminal and run the hungry client script. Both the Flask backend (views.py) and the Redis server must be running for this to work properly.
#
# View the [Solution Code](https://github.com/udacity/APIs/tree/master/Lesson_4/13_BargainMart/Solution%20Code) for this exercise.
#
# #### Answer:

# %%
id = 'iRc7BxbSCcs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 15: Lesson 4 Wrap Up

# %%
id = 'n6r7yynP0rY'
YouTubeVideo(id=id, width=600)
