# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 11: What's and Why's of APIs
#
#
# ## CHAPTER 1: Course Intro

# %%
id = 'wrKjdclSXGU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Prerequisites

# %%
id = '02Gbs2ooGFQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Want to brush up on your Python, Flask, and SQLAlchemy skills?
#
# Go ahead and check out [Full Stack Foundations](https://www.udacity.com/course/full-stack-foundations--ud088) to make sure you have an understanding of the python topics used in this course.
#
# Documentation for [Flask](http://flask.pocoo.org/docs/0.10/) and [SQLAlchemy](http://docs.sqlalchemy.org/en/rel_1_0/) can be found here as well.
#
# The [Authentication and Authorization](https://www.udacity.com/course/authentication-authorization-oauth--ud330) will come in handy when we cover API Security.
#
# Checkout these instructions for configuring the [Vagrant machine](https://www.udacity.com/wiki/ud388/vagrant) for this course.
#
# You will also need [Google Developer](https://console.developers.google.com/) and [Foursquare Developer](https://developer.foursquare.com/) accounts for this course.
#
#
# ## CHAPTER 3: What are APIs

# %%
id = 'M4Kspm_6RDg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Web APIs

# %%
id = '_49_6pjTXiQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Web API Protocols

# %%
id = 'dug9LguETqU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Learn more about the [OSI Model](https://en.wikipedia.org/wiki/OSI_model).
#
# ## CHAPTER 6: Digging into The Application Layer

# %%
id = 'zgGdBHB-yCI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: The Web Service Layer

# %%
id = 'AyQboo5CycM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# __Update__: While SOAP is still used in some contexts, RESTful APIs currently dominate the API landscape. It is no longer an 'up and coming' technology, but rather simply the best practice for API development.
#
#
# ## CHAPTER 8: Content Formatting Layer

# %%
id = 'hTdYO7tKh_k'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Choosing the Right Technologies Soap vs Rest

# %%
id = 'aI1DSeZAEMA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: XML vs JSON

# %%
id = '95X-pHvGBnw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 11: Quiz1: Developer Discussions
#
# ![api1.png](attachment:api1.png)
# #### Answer:
# *SOAP*
#
# ## CHAPTER 12: Quiz2: Developer Discussions
#
# ![api2.png](attachment:api2.png)
# #### Answer:
# *JSON*
#
# ## CHAPTER 13: Quiz3: Developer Discussions
#
# ![api3.png](attachment:api3.png)
# #### Answer:
# *HTTP*
#
# ## CHAPTER 14: REST Constraints

# %%
id = 'IvHMM0huDZk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View Thomas Fielding's [dissertation on REST](https://www.ics.uci.edu/~fielding/pubs/dissertation/rest_arch_style.htm).
#
#
# ## CHAPTER 15: Why Stateless?
#
# ![api4.png](attachment:api4.png)
# #### Answer:
# *RESTful requests can be used by multiple clients as the result the server can be updated by numerous clients.*
#
# ## CHAPTER 16: Lesson 1 Wrap Up

# %%
id = 'zEQdHAnNxhQ'
YouTubeVideo(id=id, width=600)
