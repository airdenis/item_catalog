# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 8: Adding Facebook and other providers
#
# ## CHAPTER 1: Adding Additional OAuth Providers

# %%
id = 'sy452wLnv4Q'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Registering your App with Facebook

# %%
id = '3FRNU35Km2s'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The [Facebook Developers Page can be found here](https://developers.facebook.com/).
#
# The [fb_client_secrets.json](https://github.com/udacity/ud330/blob/master/Lesson4/step2/fb_client_secrets.json) file can be found here.
#
# ### Note:
#
# Facebook has changed recently and only allows to use HTTPS protocol for redirect urls, please follow the following steps to be able to use localhost:
#
# 1. Create an Application.
# 2. Configure the URL site as: http://localhost:5000/
# 3. Create a Test Application from the button in the apps dropdown.
# 4. Don't change the default values.
# 5. Use in your application code the Test Application Application Id and Secret phrase
#
#
# ## CHAPTER 3: Client-Side Login with Facebook SDK

# %%
id = 'CFQHeWkTciE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Quiz: Updating login.html

# %%
id = 'bM44hlBH3gU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# View [login.html](https://github.com/udacity/ud330/tree/master/Lesson4/step1/templates/login.html) with Facebook login
#
#
# ## CHAPTER 5: Update project.py (part I)

# %%
id = '0duUHk-Bqy8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# __Important__: Facebook has updated their API since this course was released. This affects code that is shown in this video at 0:32 on line 194. Instead of...
# ```python
# url = 'https://graph.facebook.com/v2.2/me?%s' % token
# ```
# ... the code must be...
# ```python
# url = 'https://graph.facebook.com/v2.8/me?access_token=%s&fields=name,id,email' % token
# ```
# Here is some more information about the change:
#
# An app can make calls to the version of the API that was the latest available when the app was created, as well as any newer, un-deprecated versions launched after the app is created.
#
# Here is the main change from version 2.2 that will impact Full-Stack students:
#
# Fewer default fields for faster performance: To help improve performance on mobile network connections, we've reduced the number of fields that the API returns by default. You should now use the ``?fields=field1,field2`` syntax to declare all the fields you want the API to return.
#
# They say "we've reduced the number of fields that the API returns by default." This is important because one of the fields that is no longer returned by default is the ``email`` field. You must now explicitly request email to be returned (along with the other fields you want).
#
# The API version 2.2 that was used in this course has been officially deprecated by Facebook as of March 25th, 2017. Requests made to that version will no longer work. Please use the most current version of the Facebook API with your project code.
#
#
# ## CHAPTER 6: Update project.py (part II)

# %%
id = 'bGN2d9HKvNY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Quiz: Updating project.py Code

# %%
id = 'WySVIbTfT90'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# In order to properly log out of Facebook, the access token needs to be sent along with the facebook id in fbdisconnect. Please see the new code in the fbconnect and fbdisconnect methods in the [project.py](https://github.com/udacity/ud330/tree/master/Lesson4/step2/project.py) file.
#
# View the code for this activity on [GitHub](https://github.com/udacity/ud330/tree/master/Lesson4/step2)
#
#
# ## CHAPTER 8: Exploring other OAuth2.0 Providers

# %%
id = 'gtibSNC0KcI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Check out some of these links below to add OAuth 2.0 using these other popular providers:
#
# * [OAuth 2.0 with Amazon](http://login.amazon.com/website)
# * [OAuth 2.0 with Github](https://developer.github.com/v3/oauth/)
# * [OAuth 2.0 with Paypal](https://developer.paypal.com/docs/integration/direct/paypal-oauth2/)
#
#
# ## CHAPTER 9: Outro

# %%
id = '1UzLe18r_Xo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The final code for this project can be found on [GitHub](https://github.com/udacity/ud330).
#
# Here is the [Offical OAuth 2.0 website](http://oauth.net/2/) .
