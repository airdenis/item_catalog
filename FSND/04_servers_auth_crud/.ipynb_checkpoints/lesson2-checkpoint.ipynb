# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 2: Making a Web Server
#
# ## CHAPTER 1: Introduction

# %%
id = 'oqq0ClT5fcw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Review of Clients, Servers and Protocols

# %%
id = 'gE5WUbmb6Cc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: HTTP and Response Codes

# %%
id = 'K7h1PzqNgOs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# __Errata__: At 1:05 in the above video, the instructor states that a ``301`` status code is used for a successful POST request. The ``301`` status code is a permanent redirect, used to send a browser to a different URL. More common status codes for a successful POST are ``200``, ``201``, and ``303``. For much more information, see [MDN on HTTP status codes](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status).
#
# ## CHAPTER 4: Building a Server with HTTPBaseServer

# %%
id = '2FwNy4Gxyh4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * Python Documentation on [HTTPBaseServer](https://docs.python.org/2/library/basehttpserver.html)
# * Click to view the code for [webserver.py](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/first-web-server/webserver.py)
#
#
# ## CHAPTER 5: Quiz: Running a Web Server

# %%
id = '1yMH2EX7ArA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * Click here to view the code for [webserver.py](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/first-web-server/webserver.py)
# * Supporting Materials [webserver.py](https://www.udacity.com/api/nodes/3608298706/supplemental_media/webserverpy/download)
#
# ## CHAPTER 6: Port Forwarding
#
# ### Port Forwarding
#
# Your [Vagrant File](https://github.com/udacity/fullstack-nanodegree-vm/blob/master/vagrant/Vagrantfile) for this course looks something like this:
#
# Vagrant File Image
# Port forwarding allows us to open pages in our browser from the web server from our virtual machine as if they were being run locally. See which ports are being used for this class. If you want to use another port you can add another line to the vagrant file and run "vagrant reload" from a terminal in the directory of your vagrant file on your host machine. More information about port forwarding is available [here ](https://docs.vagrantup.com/v2/networking/forwarded_ports.html).
#
# ## CHAPTER 7: Responding to Multiple GET Requests

# %%
id = 'bycHjpMyHrc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Click to view [webserver.py](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/hola-server/webserver.py) with hola functionality.
#
# ## CHAPTER 8: Hola Server

# %%
id = 'tyj7_lzB8BQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * Click to view [webserver.py](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/hola-server/webserver.py) with hola functionality.
# * Supporting Materials [webserver.py](https://www.udacity.com/api/nodes/3608298708/supplemental_media/webserverpy/download)
#
# ## CHAPTER 9: Adding POST to web server

# %%
id = 'CG5-slb_mWY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Running the POST Web Server

# %%
id = 'LYwFtzXEn98'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Click to view [webserver.py](https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/post-web-server/webserver.py) with POST functionality.
#
# ## CHAPTER 11: CRUD Objectives
# ![crud1.png](attachment:crud1.png)
#
# ## CHAPTER 12: Adding CRUD Hints

# %%
id = 'B2rcdHCVgCI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Follow the links below to view:
# * [Python 2.7.9 Documentation](http://www.docs.python.org/2/)
# * [Chrome Developer Tools](http://developer.chrome.com/devtools)
#
# ## CHAPTER 13: Quiz: CRUD Hints
#
# ![crud2.png](attachment:crud2.png)
#
# ## CHAPTER 14: Quiz: Objective 1

# %%
id = 'S_Znub-Bwkg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Error in video - Replace lines 12 and 13 with:
# ```python
# DBSession = sessionmaker(bind=engine)
#
# session = DBSession()
# ```
# Objective 1 solution can be found here:
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/Objective-1-Solution/webserver.py
#
#
# #### Note:
#
# A few times I say backslash "\\" in this course, all slashes in this course should be forward slashes "/"
#
# #### Supporting Materials
# [webserver.py](https://www.udacity.com/api/nodes/3608298714/supplemental_media/webserverpy/download)
#
# ## CHAPTER 15: Quiz: Objective 2

# %%
id = 'deeuXkvDGMQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Objective 2 Solution Code can be found here: https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/Objective-2-Solution/webserver.py
#
# Supporting Materials
# [webserver.py](https://www.udacity.com/api/nodes/3608298718/supplemental_media/webserverpy/download)
#
# ## CHAPTER 16: Quiz: Objective 3

# %%
id = '-CRtdrGKQe0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# __Note__
#
# ``messagecontent = fields.get('newRestaurantName')`` should be indented such that it is inside the 'if' block
#
# ### Objective 3 Solution Code can be found here:
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/Objective-3-Solution/webserver.py
#
# #### Supporting Materials
# [webserver.py](https://www.udacity.com/api/nodes/3608298721/supplemental_media/webserverpy/download)
#
# ## CHAPTER 17: Quiz: Objective 4

# %%
id = 'pTSscIELZcA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Objective 4 Solutions can be found here:
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/Objective-4-Solution/webserver.py
#
#
# ## CHAPTER 18: Quiz: Objective 5

# %%
id = 'ap51NDGX1_s'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Note
#
# line 128 (ctype, pdict....) is not a necessary line of code to implement this solution.
#
# ### Code for Objective 5 can be found here:
#
# https://github.com/udacity/Full-Stack-Foundations/blob/master/Lesson-2/Objective-5-Solution/webserver.py
#
# #### Supporting Materials
# [webserver.py](https://www.udacity.com/api/nodes/3608298727/supplemental_media/webserverpy/download)
#
# ## CHAPTER 19: Lesson 2 Wrap-Up

# %%
id = 'vwbWjzKnAQw'
YouTubeVideo(id=id, width=600)
