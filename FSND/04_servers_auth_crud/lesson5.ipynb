# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 5: Authentication vs Authorization
#
# ## CHAPTER 1: Intro

# %%
id = 'glvbO-RcAbY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# [Learn Ajax](https://www.udacity.com/course/ud110)
#
# [Learn jQuery](https://www.udacity.com/course/ud245)
#
# Set up your [Google](https://www.google.com/) account.
#
# Set up your [Facebook](https://www.facebook.com/) account.
#
# ## CHAPTER 2: Course Map

# %%
id = '4WMBP08gmbA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Check out Udacity's awesome course on [Applied Cryptography](https://www.udacity.com/course/cs387) if you are interested in learning more about these concepts
#
# [Here](http://lepture.com/en/2013/create-oauth-server) is a blog on creating a your own auth system with Flask.
#
#
# ## CHAPTER 3: Authentication

# %%
id = 'ATB23YVOSq4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Quiz: Authentication is hard

# %%
id = 'rAnBQSQuwa0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'xvENj49qyQk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Quiz: Implementing Authentication is Hard

# %%
id = 'kHMKOcwSN3c'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Read more about:
#
# [App for Checking password security](https://howsecureismypassword.net/)
#
# [Password Storage - Hashing vs. Encrypting](http://www.darkreading.com/safely-storing-user-passwords-hashing-vs-encrypting/a/d-id/1269374)
#
# [Man-in-the-Middle Attacks](http://en.wikipedia.org/wiki/Man-in-the-middle_attack)
#
#
# #### Answer:

# %%
id = 'lTaQmTXeErE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Using Third Party Auth Providers

# %%
id = '99skRCpY6Po'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Authorization

# %%
id = 'lyHrVjx8MSw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: Authentication without Authorization

# %%
id = 'TdAze0W7CEw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Quiz Question
#
# Label these actions based on whether they require authorization, authentication or both.
#
# ---
#
# Authentication OR
#
# Both
#
# Action | Security Method
# ------|----
# Logging into a Unix System | Authentication
# Accessing a file on a filesystem | Authorization
# Opening a password-protected zip file | Authorization
# Crossing a border into another country | Both
#
# [Session Hijacking](http://en.wikipedia.org/wiki/Session_hijacking) occurs when an attacker gains access to a users session cookie and can make requests upon their behalf.
#
# ## CHAPTER 9: Auth providers

# %%
id = 'rSEGRlna8XY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Pros and Cons using Third Party

# %%
id = 'bbpjxXImqTY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 11: Quiz: Follow the Flow

# %%
id = 'j3NyYrpmbCw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# https://developers.google.com/oauthplayground/
#
#
# ## CHAPTER 12: Outro

# %%
id = 'xcSy6Su9B-s'
YouTubeVideo(id=id, width=600)
