# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# ## LESSON 12: Accessing Published APIs
#
# ### CHAPTER 1: Lesson 2 Intro

# %%
id = '5nWz7OmRxjU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Parts of an HTTP Request

# %%
id = 'pHFWGN-upGM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: HTTP Response

# %%
id = 'c9sMNc2PrMU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Sending API Requests with Postman and Curl

# %%
id = 'U_mbqqkM9mg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Check out the official cURL [documentation](http://curl.haxx.se/docs/manpage.html) and [this blog post](http://www.ethanmick.com/getting-started-with-curl/) for getting started with cURL.
#
# Check out the [Postman Documentation](https://www.getpostman.com/docs) as well.
#
# You should also be familiar with [query strings](https://en.wikipedia.org/wiki/Query_string) as option to pass in variables straight from the URI.
#
#
# ## CHAPTER 5: Quiz: Sending API Requests

# %%
id = 'LRKb7bPcGaw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Download the code for [api_server.py here](https://github.com/udacity/APIs/blob/master/Lesson_2/06_Sending%20API%20Requests/api_server.py).
#
# There are some exceptions, but for most use cases:
#
# * __HTTP <--> CRUD__
# * GET <--> READ
# * POST<--> CREATE
# * PUT <--> UPDATE/CREATE
# * PATCH <--> UPDATE
# * DELETE-<-->DELETE
#
# ![api5.png](attachment:api5.png)
# #### Answer:
# * GET  --> *Hi, I got your GET Request!*
# * POST --> *I see you sent a POST message :-)*
# * PUT  --> *Sending Hello on an PUT request!*
# * DELETE --> *Deleting your hard drive.....haha just kidding! I received a DELETE request!*
#
# ## CHAPTER 6: Searching for API Documentation

# %%
id = 'aqZc9aky2WU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Errata:
#
# As of December 2017, SoundCloud is no longer accepting new API sign-ups.
#
#
# ## CHAPTER 7: Delving Into APIs

# %%
id = 'OZdhXtpMYpQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * [Google Maps API](https://developers.google.com/maps/?hl=en)
# * First, get your [Google Maps API key](https://developers.google.com/maps/documentation/geocoding/get-api-key)
# * Then use the [Google Maps Geocoding API](https://developers.google.com/maps/documentation/geocoding/intro).
#
#
# ![api6.png](attachment:api6.png)
#
#
# ## CHAPTER 8: Quiz: Using the Foursquare API

# %%
id = 'mHlasP-fP9w'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Here's the [Foursquare API](https://developer.foursquare.com/).
#
# You may have realized that Foursquare has a geolocating capability as well, but since you already learned how to use the google maps one, you might as well put it to good use ;-)
#
# You can copy and paste the coordinates below: Mountain View, California (37.392971, -122.076044)
# Miami, Florida (25.773822, -80.237947)
# Washington, DC (38.897478, -77.000147)
# New York, New York (40.768349, -73.96575)
#
# ![api7.png](attachment:api7.png)
#
# ## CHAPTER 9: Requesting From Python Code

# %%
id = 'WrBRxsumxaM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Parsing Your Response

# %%
id = 't5LoFkbGXcM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Check out the [geocode.py](https://github.com/udacity/APIs/blob/master/Lesson_2/10_Requesting%20from%20Python%20Code/geocode.py) file from this activity.
#
#
# ## CHAPTER 11: Quiz: Make Your Own API Mashup

# %%
id = 'ebPacNWlVps'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Download the [starter code](https://github.com/udacity/APIs/tree/master/Lesson_2/12_Make_Your_Own_Mashup/starter_code) for this exercise.
#
# View the [solution code](https://github.com/udacity/APIs/tree/master/Lesson_2/12_Make_Your_Own_Mashup/solution_code) for this exercise.
#
#
# ## CHAPTER 12: Lesson 2 Wrap Up

# %%
id = 'GEnz-eS0GtI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Some Interesting APIs to Explore
#
# * [Wikipedia API](https://www.mediawiki.org/wiki/API:Main_page)
# * [StackExchange API](https://api.stackexchange.com/)
# * [Google Maps API](https://developers.google.com/maps/)
