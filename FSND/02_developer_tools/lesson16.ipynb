# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 16: Addressing and Networks
#
# ## CHAPTER 1: Intro

# %%
id = 'FppVqIfR1Es'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Special Addresses

# %%
id = 'zk3CCX_GfA8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Reserved IP addresses
#
# ### Reserved IP addresses
#
# An IPv4 address is actually a 32-bit numeric value. We usually write it as a *dotted quad* — four decimal numbers, separated by dots, like ``206.190.36.45`` or ``180.149.132.47``. Each of the four numbers written down like this represents one octet or 8-bit value.
#
# But writing an IP address as four decimal numbers is just a convention to make it easier to read. When it’s used between computers, an address is transmitted in binary, just like all the other data sent over the network.
#
# However, not all of the possible 32-bit values are used for real addresses. Some of them are used for special applications that use addresses differently. Some of them are reserved for internal private networks. Some of them are for testing or documentation.
#
# Here's a visualization of the entire IPv4 address space. Each square represents one possible value of the first octet of an address. For instance, the square on the top right, labeled ``15``, represents all the IPv4 addresses that start with ``15`` as their first octet.
#
# ![unnamed.png](attachment:unnamed.png)
#
# * The light-green squares (``0``, ``10``, and ``127``) are blocks that are entirely reserved.
# * The dark-green squares are blocks that are partly reserved. For instance, not all of the ``192`` block is reserved, but some of it is.
# * The entire cyan row (starting at ``224``) is set aside for [IP multicast](https://en.wikipedia.org/wiki/IP_multicast).
# * And the entire orange bottom row (starting at ``240``) was [originally set aside for "future use" but was effectively lost due to being blocked as invalid](http://packetlife.net/blog/2010/oct/14/ipv4-exhaustion-what-about-class-e-addresses/). No, really. We lost 1/16th of all IPv4 addresses due to mistaken planning.
#
# In fact, just *over one-eighth* of all possible IPv4 addresses are set aside for something other than addressing public hosts. But as you'll see, even if we did use all 32-bit addresses to represent public hosts, that still wouldn’t really be enough.
#
# ## CHAPTER 4: Quiz: How Many Addresses

# %%
id = 'YQLMdzPCBQ0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'pHai1tA75Bc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Netblocks and Subnets

# %%
id = 'e-AoilQ8v6o'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Quiz: Subnet Masks

# %%
id = 'IkGw5BIxZGE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'fZ9oCc-NGGo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Quiz: Stanford's/14

# %%
id = 'uAid90W8Y78'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'tGLPE_UugN0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: Not Enough Addresses

# %%
id = '8R3Q9u1_XHw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: The Host is a Lie

# %%
id = 'vH8raiRvJlk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Quiz: Interfaces Quiz

# %%
id = 'Vk7-g7Cvrec'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'niI94j_OYgs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 11: Routers and Default Gateways

# %%
id = 'JOomC1wFrbU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 12: Quiz: Default Gateway Quiz

# %%
id = '_lF2B6G_1rQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'SKu8AfsGCVY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 13: NAT

# %%
id = 'IFcIeN0EmgM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 14: Quiz: Private and Public

# %%
id = 'XQjmXmA7tmY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'J1w3BU6Cd60'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 15: IPv6

# %%
id = 'FXi7U8u-5sc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 16: Quiz: IPv6 Quiz

# %%
id = '3V735AXl644'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'JjFC4tw-wG8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 17: Outro

# %%
id = 'SHftDECOEdE'
YouTubeVideo(id=id, width=600)
