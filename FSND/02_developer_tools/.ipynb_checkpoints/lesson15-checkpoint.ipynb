# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 15: Names and Addresses
#
# ## CHAPTER 1: Intro

# %%
id = 'w8HdeShedF0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2:  Quiz: Ping a Hostname

# %%
id = '_yVXp3fbukQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'xSRBfU0D_Oo'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Intro to DNS

# %%
id = 'RbNlFy7fWhw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Quiz: The host command

# %%
id = 'JrMG5bj5Ads'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'XU-hMgf-p8A'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Dig into DNS Records

# %%
id = '0MrzjVhIKFQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Quiz: Research DNS Record Types

# %%
id = 'PyUiurkGWTQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'YD-B6zHDPIw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: DNS is Distributed with Caching

# %%
id = 'K4C_L_ZFXIU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: DNS and HTTP

# %%
id = '4LDkdKqlVwQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Subdomains and FQDNs

# %%
id = '1yD9qZyxF_A'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Quiz: Register a Domain

# %%
id = 'koNZ4U1EVx0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = '_ku1X8IQDMc'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 11: 32 bits to 128 bits

# %%
id = 'ghZtmd0GYos'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 12: 8 Bits in a Byte

# %%
id = 'fXzLSLBd_x8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 13: Quiz: Bits

# %%
id = '8xHjyLkjo4Y'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'yuHnHfasFII'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 14: Quiz: Bits in a Port Number

# %%
id = '6WqKoZEoFHM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = '8-5iJcVGwwY'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 15: Outro

# %%
id = '2J738mJOXpc'
YouTubeVideo(id=id, width=600)
