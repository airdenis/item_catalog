# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 1: Shell Workshop
#
#
# ## CHAPTER 1: Welcome!

# %%
id = '-EtN5oD8MM0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Windows: Installing Git Bash

# %%
id = 'UQZvV6VTlGQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# **Reminder: This page is Windows-only! Mac and Linux users, skip ahead to the next page!**
#
# Download Git here: [https://git-scm.com/download/win](https://git-scm.com/download/win)
#
# **Note**: There is a new Linux compatibility system in Windows 10, called Windows Subsystem for Linux (WSL). If you've heard of it, you may be wondering why we don't use that in this course. It's an experimental mini-Linux-OS that runs inside Windows, like a virtual machine. You can access your Windows files from inside it, but it's a little bit dangerous to share files between the Linux and Windows sides. In the future, WSL will probably become less experimental, but for now we'll be using Git Bash instead for this course.
#
#
# #### TO DO
# Install Git Bash on your Windows computer.
#
# - I have downloaded Git from git-scm.com
# - I have installed Git.
# - I have found the Git Bash application and run it.
# - I have adjusted the front to something comfortable for me

# %% [markdown]
# ## CHAPTER 3: Opening a terminal

# %%
id = '4q6Vtym-nno'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### TO DO
#
# *open a terminal!*
#
# - I have a terminal open in another window.

# %% [markdown]
# ## CHAPTER 4: Your first command (echo)

# %%
id = 'ggf5WhOYy1U'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ
# What do you think is going on when you run this command:
# `` echo $COLUMNS x $LINES ``
# (try it!)
#
# 1. The terminal is multiplying dollars by dollars.
# 2. The shell is telling me how big my terminal is.(correct)
# 3. The shell is telling me how big its army is.
# 4. The terminal is erasing all my files.

# %% [markdown]
# ## CHAPTER 5: Navigating directories (ls, cd, ..)

# %%
id = 'i9Xp94DmdB8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ
#
# Which of these commands would list the contents of the Pictures directory?
# Mark all that are correct.
#
# 1. ls Pictures
# 2. cd Pictures; ls
# 3. ls Pictures/../Pictures
#
# All above are correct!

# %% [markdown]
# ## CHAPTER 6: Current working directory (pwd)

# %%
id = 'X7dsy3oMHp0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ
#
# Why are shell commands so short?
#
# 1. It makes for less typing.(correct)
# 2. It makes them easier to remember.
# 3. It makes Unix experts look wizardly.

# %% [markdown]
# ## CHAPTER 7: Parameters and options (ls -l)

# %%
id = 'UX9mzq11Mmg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ 1
#
# Which pieces of information can you find out from ``ls -l``? You may want to do some research to answer this question; use your favorite search engine.
#
# 1. The name of each listed file or directory. (correct)
# 2. The date and time that a file was last modified. (correct)
# 3. The size of a file, in bytes. (correct)
# 4. Whether a file has been checked for viruses
#
# ### QUIZ 2
#
# If you wanted to list all the files whose names start with the word ``bear``, how would you do it?
#
# 1. ``ls bear``
# 2. ``ls *.bear``
# 3. ``ls bear*`` (correct)
# 4. ``ls *bear*``

# %% [markdown]
# ## CHAPTER 8: Organizing your files (mkdir, mv)

# %%
id = 'NZsYyzzpJXA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ
#
# Let's say I change my mind and want to move the ``epub`` files back from ``Documents/Books`` to ``Documents``. How can I do this? My current working directory is my home directory, and ``Documents`` is inside that directory.
# Mark each answer that would work:
#
# 1. ``mv 'Documents/Books' Documents``
# 2. ``mv Documents/Books* Documents`` (correct)
# 3. ``cd Documents; mv Books/*.epub .`` (correct)
# 4. ``cd Documents/Books; mv * ..`` (correct)
#
#
# By the way, when you quote something in the shell, you always use straight quotes. This is what you'll get if you type into a terminal window. However, if you copy and paste from a web page or document, you should be really careful to make sure that it hasn't accidentally been written with ``“curly quotes”``. Curly quotes will not work in the shell.
#
# Single quotes and double quotes do slightly different things in the shell. If you're unsure which to use, go for single quotes.

# %% [markdown]
# ## CHAPTER 9: Downloading (curl)

# %%
id = 'h7FhU1f4TgE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ
#
# Download \`dictionary.txt\`
#
# Enter a shell command to download ``https://tinyurl.com/zeyq9vc`` and save it as the file ``dictionary.txt``. Remember to use the option to follow web redirects.
#
# Run this command on your own computer, too! You'll need to download this file for the next exercise.
#
# #### Answer
# ``curl -o dictionary.txt -L 'https://tinyurl.com/zeyq9vc'``
#
#
# ### Solution

# %%
id = '1oEJUA-b0kE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 10: Viewing files (cat, less)

# %%
id = 'hPPVMKqbQV0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ
#
# What's the next word?
#
# Using the ``dictionary.txt`` file and the ``less`` command, find out the next word after the word ``goobers`` in this dictionary.
#
# #### Answer
# good

# %% [markdown]
# ## CHAPTER 11: Removing things (rm, rmdir)

# %%
id = 'it19PvJarbk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Quiz Question
#
# You have four files named:
#
# 1. ``Good File``
# 2. ``Bad Name Good File``
# 3. ``Bad File``
# 4. ``Good Name Bad Face``
#
# You want to remove files 3 and 4, while leaving 1 and 2 intact. There are two commands below that will accomplish this goal. Choose them:
#
# - ``rm 'Bad File' 'Good Name Bad Face'`` (correct)
# - ``rm *Bad*``
# - ``rm Bad!Good``
# - ``rm *'Bad F'*`` (correct)

# %% [markdown]
# ## CHAPTER 12: Searching and pipes (grep, wc)

# %%
id = 'AWpVScp9z4s'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### QUIZ 1
# Looking for `ibo`
#
# How many words are there in ``dictionary.txt`` that match the pattern ``ibo``?
#
# #### Answer:
# 22
#
# ### QUIZ 2
# What are grep patterns called?
#
# Research question! You can use ``grep`` for more than just matching words. There's a specific term for the patterns that ``grep`` lets you use.
#
# Use your favorite search engine and do a little research to find out what those patterns are called.
#
# #### Answer:
# regular expression

# %% [markdown]
# ## CHAPTER 13: Shell and environment variables

# %%
id = 'Dx3WlMZk8iA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Question 1 of 2
#
# Do you think the ``PWD`` variable is a shell variable or an environment variable?
#
# (Don't know what it is? Try ``echo $PWD``)
#
# - Shell variable
# - Environment variable (correct)
#
# ### Question 2 of 2
#
# Display two variables
#
# Write a shell command using echo that displays the contents of the variables ``LOGNAME`` and ``PWD`` with a space between them.
#
# #### Answer:
# ``echo $LOGNAME $PWD``

# %% [markdown]
# ## CHAPTER 14: Startup files (.bash_profile)

# %%
id = '-zF-XebfzBE'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 15: Controlling the shell prompt ($PS1)

# %%
d = 'nnqvRZ-Fx3k'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Near the end of the video, there's a screenshot of the tool I used to construct the long and complex ``$PS1`` prompt. The tool is [http://bashrcgenerator.com](http://bashrcgenerator.com) by Julien Ricard. Try it out!

# %% [markdown]
# ## CHAPTER 16: Aliases

# %%
d = 'kINmpgXxayM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 17: Keep learning!

# %%
d = '68twTPXPrx0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ### Shell resources
#
# * [The Bash Academy](https://www.bash.academy/)
# * [Bash Beginners Guide](http://www.tldp.org/LDP/Bash-Beginners-Guide/html/)
# * [Bash Programming HOWTO](http://tldp.org/HOWTO/Bash-Prog-Intro-HOWTO.html)
# * [Regexr — Learn Regular Expressions](https://regexr.com/)
