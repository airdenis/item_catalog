# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 1: Data and Tables
#
# ## CHAPTER 1: Welcome to Relational Databases

# %%
id = 'skSSxx2fjsI'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: What's a Database

# %%
id = 'V4gbPVdUOpw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: Quiz: Looking at Tables

# %%
id = 'e8zSXnyskro'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * Here's the table for this quiz:
# 1. country 	population 	literacy
# 2. Argentina 	43 million 	98%
# 3. Brazil 	203 million 	91%
# 4. Colombia 	47 million 	94%
# 5. Ecuador 	15 million 	92%
# 6. ... 	... 	...
#
# #### Answer:

# %%
id = '08GsrEIOP9Q'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Quiz: Data Types and Meaning

# %%
id = 'OB7iJnEY0Tg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = 'Bb2K_pql26Y'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Quiz: Data Meanings

# %%
id = '-laXTx9corQ'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = '0-LYyC_70jk'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: Zoo

# %%
id = 'YG8zfeRXAvM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: Anatomy of a Table

# %%
id = 'PhvA7DCgtpw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * Here's the table from the video.
#
# * animals:
# * name string 	species string 	birthdate date
# 1. Max 	gorilla 	2001-04-13
# 2. Sue 	gorilla 	1998-06-12
# 3. Max 	moose 	2012-02-20
# 4. Alison 	llama 	1997-11-24
# 5. George 	gorilla 	2011-01-09
# 6. Spot 	iguana 	2010-07-23
# 7. Ratu 	orangutan 	1989-09-15
# 8. Eli 	llama 	2002-02-22
#
#
# ## CHAPTER 8: Quiz: Answering Questions from a Table

# %%
id = 'tt-XjT9RdDg'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# * Here's the table for this quiz.
# animals:
#
# name string |	species string |	birthdate date
# -----------------|----------|----------------
# Max |	gorilla |	2001-04-13
# Sue |	gorilla |	1998-06-12
# Max |	moose |	2012-02-20
# Alison |	llama |	1997-11-24
# George |	gorilla |	2011-01-09
# Spot |	iguana |	2010-07-23
# Ratu |	orangutan |	1989-09-15
# Eli |	llama |	2002-02-22
#
# #### Answer:

# %%
id = '52c-0doU44I'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Aggregations

# %%
id = 'TE9uvPwvpu4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# This video shows the results of a ``count`` aggregation on the ``animals`` table. It's a ``count`` aggregation, grouping the values in the table using the ``species`` column. In other words, it's counting the number of rows that have the same value in that column.
#
# Here's the table we start with:
#
# | name string |	species string |  birthdate date |
# --------------|:---------------|:---------------:|
# | Max         |	gorilla        |	2001-04-13   |
# | Sue         |	gorilla        |	1998-06-12   |
# | Max         |	moose          |	2012-02-20   |
# | Alison      |	llama          |	1997-11-24   |
# | George      |	gorilla        |	2011-01-09   |
# | Spot        |	iguana         |	2010-07-23   |
# | Ratu        |	orangutan      |	1989-09-15   |
# | Eli         |	llama          |	2002-02-22   |
#
# And here's the result of the aggregation:
#
# species string | 	count integer
# -------|-------
# gorilla |	3
# moose |	1
# llama |	2
# iguana |	1
# orangutan |	1
#
#
# ## CHAPTER 10: Quiz: Queries and Results

# %%
id = 'ZFn9xVQ0hD4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# In a relational database, when there are multiple answers to a question (like "What do brown bears eat?") they will usually appear as multiple rows in a table.
#
# Here's the table from this quiz:
#
# ### diet:
#
# species string |	food string
# ----------------|--------------
# llama |	plants
# brown bear |	fish
# brown bear |	meat
# brown bear |	plants
# orangutan |	plants
# orangutan |	insects
#
# ## CHAPTER 11: How Queries Happen

# %%
id = 'v3EkXogyIL4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 12: Favorite Animals

# %%
id = 'O7kWdC8ffEw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Check out Kittenwar: http://www.kittenwar.com/
#
# ## CHAPTER 13: Related Tables

# %%
id = 'lMwSjDYgCq0'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Here are the tables from this video.
#
# The __pictures__ table stores the names of cute animals and the filenames of their pictures.
#
# id |	name |	filename
# ----|---|--
# 1 |	Fluffy |	fluffsocute.jpg
# 2 |	Monster |	monstie-basket.png
# 3 |	George |	george.jpg
# ... |	... |	...
#
# The __votes__ table stores information about which pictures have been displayed together, and which one the user voted for:
#
# left |	right |	winner
# -----|-----|-----
# 2 |	3 |	3
# 1 |	3 |	1
# 2 |	1 |	1
# 3 |	2 |	3
# 3 |	1 |	1
# 2 |	3 |	3
# ... |	... |	...
#
# We can ask the database to __join__ these tables, to look up the animal names for each of the votes:
#
# left_name |	right_name |	winner_name
# --------|----------|------
# Monster |	George |	George
# Fluffy |	George |	George
# Monster |	Fluffy |	Fluffy
# George |	Monster |	George
# George |	Fluffy |	Fluffy
# Monster |	George |	George
# ... |	... |	...
#
# ## CHAPTER 14: Uniqueness and Keys

# %%
id = 'TIayTr4y9RA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# The examples in the video are not made up! [There actually are five Springfields in the state of Wisconsin](https://en.wikipedia.org/wiki/Springfield,_Wisconsin).
#
# Country names are not actually as unique as I said in the video, though. There's only one France, but there are two Congos. That is, as of 2016 there are two countries often called "Congo": the Democratic Republic of the Congo, also known as Congo-Kinshasa and previously known as Zaire; and the Republic of the Congo, also known as Congo-Brazzaville.
#
# A better primary key for countries exists, though: the international community has established standard [country codes](https://en.wikipedia.org/wiki/ISO_3166), unique abbreviations for each country. Congo-Kinshasa has country code ``CD``, while Congo-Brazzaville is ``CG``. These are also their Internet top-level domain names.
#
# ## CHAPTER 15: Primary Key

# %%
id = 'q23Nlo1Rfn4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# #### Answer:

# %%
id = '80aFO4KmcPM'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 16: Joining Tables

# %%
id = 'lXoiI0gx3MU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# In the video, there are two tables, ``animals`` and ``diet``. Joining those tables gives us a new table, which contains information taken from the two original tables. The join statement has a join condition that tells the database how to match up the rows from one table with the rows from the other.
#
# ### Table reference
#
# Here are the tables from the video. They're the same ones as earlier in this lesson.
#
# **animals**:
#
# name string |	species string |	birthdate date
# --------|---------|-------
# Max |	gorilla |	2001-04-13
# Sue |	gorilla |	1998-06-12
# Max |	moose 	|2012-02-20
# Alison |	llama |	1997-11-24
# George |	gorilla |	2011-01-09
# Spot |	iguana |	2010-07-23
# Ratu |	orangutan |	1989-09-15
# Eli |	llama |	2002-02-22
#
# **diet:**
#
# species string |	food string
# -------|----------
# llama |	plants
# brown bear |	fish
# brown bear |	meat
# brown bear |	plants
# orangutan |	plants
# orangutan |	insects
#
# ---
# This SQL query will join the two tables to find out what foods each animal can eat:
# ```python
# select animals.name, animals.species, diet.food
#        from animals join diet
#        on animals.species = diet.species;
# ```
# You'll see much more with these tables later in the course!
#
#
# ## CHAPTER 17: Quiz: Database Concepts

# %%
id = 'WZRsqdNrC1A'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# Here are some possible column names to choose from. Not all of these are good choices; it's up to you to choose the ones that are!
# * donor
# * favorite
# * gorilla
# * home
# * mobile
# * name
# * number
# * phones
# * phone_type
# * phone_number
# * type
#
# ## CHAPTER 18: Summary

# %%
id = '1Gp4l-ZTCVk'
YouTubeVideo(id=id, width=600)
